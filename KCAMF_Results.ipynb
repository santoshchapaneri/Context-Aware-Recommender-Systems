# %%
import numpy as np

import matplotlib.pyplot as plt

font = {'family' : 'monospace',
        'weight' : 'normal',
        'size'   : 16}

plt.rc('font', **font)

# %% [markdown]
# # **Results**

# %%
F = np.array([10, 20, 30, 40, 50, 60, 70, 80])
BMF= np.array([1.2255,1.1943,1.178,1.1971,1.1864,1.1815,1.1831,1.1778])
SVDpp= np.array([1.0825,1.0625,1.0605,1.0561,1.0508,1.0554,1.0525,1.0591])
PMF= np.array([1.0715,1.0706,1.0626,1.0655,1.0648,1.0638,1.0627,1.0753])
NMF= np.array([1.0641,1.0631,1.0751,1.0613,1.0577,1.0564,1.0611,1.0574])
CPTF= np.array([1.5872,1.5488,1.648,1.4888,1.5586,1.7014,1.5438,1.5987])
CAMF= np.array([0.9996,0.9701,0.9599,0.9534,0.9513,0.9483,0.9501,0.9431])
ICAMF= np.array([0.9943,0.9677,0.9521,0.9493,0.9405,0.9352,0.9317,0.9284])
Prop= np.array([0.9702,0.9386,0.9258,0.9216,0.9036,0.9012,0.9017,0.9002])

fig, ax = plt.subplots(1, 1)
ax.set(xlabel='Latent dimension', ylabel='RMSE')

ax.plot(F,BMF, 'y', linestyle='dotted', marker='*', markersize=7, label = 'BMF', linewidth = 3)
ax.plot(F,SVDpp, 'k', linestyle='dotted', marker='*', markersize=7, label = 'SVD++', linewidth = 3)
ax.plot(F,PMF, 'm', linestyle='dashed', marker='h', markersize=7, label = 'PMF', linewidth = 3)
ax.plot(F,NMF, 'c', linestyle='dashdot', marker='D', markersize=7, label = 'NMF', linewidth = 3)
ax.plot(F,CAMF, 'r', linestyle='dotted', marker='^', markersize=8, label = 'CAMF', linewidth = 3)
ax.plot(F,ICAMF, 'b', linestyle='dashdot', marker='o', markersize=8, label = 'ICAMF', linewidth = 3)
ax.plot(F,Prop, 'g', marker='s', markersize=7, label = 'KCAMF', linewidth = 3)

ax.grid()
#ax.set_ylim((0,1))
plt.xticks(F)
#ax.legend(loc='center right',prop = {'size' : 9.5})
#ax.legend(loc='center left', bbox_to_anchor=(0.6, 2),fancybox = True, shadow = True, prop = {'size' : 12})

fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.savefig('RMSE_rat.png')
plt.show()

# %%
F = np.array([10, 20, 30, 40, 50, 60, 70, 80])
BMF= np.array([1.007,0.9724,0.97,0.9954,0.9723,0.9709,0.9759,0.9685])
SVDpp= np.array([0.7366,0.7173,0.7128,0.7109,0.7074,0.7107,0.7105,0.7158])
PMF= np.array([0.7426,0.7239,0.7132,0.7186,0.7164,0.7187,0.7155,0.7261])
NMF= np.array([0.7741,0.7332,0.7327,0.7211,0.7402,0.7131,0.7158,0.7132])
CPTF= np.array([1.2223,1.2076,1.2803,1.1471,1.2117,1.3313,1.1947,1.2457])
CAMF= np.array([0.7326,0.7085,0.7304,0.7186,0.6981,0.6954,0.6882,0.6821])
ICAMF= np.array([0.7317,0.7016,0.7277,0.7103,0.6908,0.6889,0.6805,0.6783])
Prop= np.array([0.7163,0.6801,0.6764,0.6703,0.6701,0.6629,0.6629,0.6573])

fig, ax = plt.subplots(1, 1)
ax.set(xlabel='Latent dimension', ylabel='MAE')

ax.plot(F,BMF, 'y', linestyle='dotted', marker='*', markersize=7, label = 'BMF', linewidth = 3)
ax.plot(F,SVDpp, 'k', linestyle='dotted', marker='*', markersize=7, label = 'SVD++', linewidth = 3)
ax.plot(F,PMF, 'm', linestyle='dashed', marker='h', markersize=7, label = 'PMF', linewidth = 3)
ax.plot(F,NMF, 'c', linestyle='dashdot', marker='D', markersize=7, label = 'NMF', linewidth = 3)
ax.plot(F,CAMF, 'r', linestyle='dotted', marker='^', markersize=8, label = 'CAMF', linewidth = 3)
ax.plot(F,ICAMF, 'b', linestyle='dashdot', marker='o', markersize=8, label = 'ICAMF', linewidth = 3)
ax.plot(F,Prop, 'g', marker='s', markersize=7, label = 'KCAMF', linewidth = 3)

ax.grid()
#ax.set_ylim((0,1))
plt.xticks(F)
#ax.legend(loc='center right',prop = {'size' : 9.5})

fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.savefig('MAE_rat.png')
plt.show()

# %%
F = np.array([10, 20, 30, 40, 50, 60, 70, 80])
BMF= np.array([0.8923,0.8636,0.8903,0.86,0.8443,0.8712,0.8599,0.8667])
SVDpp= np.array([0.8831,0.8478,0.8289,0.8235,0.819,0.8091,0.8006,0.8003])
PMF= np.array([1.6246,1.8151,1.8991,1.9499,2.0213,2.0107,2.0201,2.0322])
NMF= np.array([1.0448,0.9855,0.9697,0.9661,0.9557,0.9558,0.9513,0.9489])
CPTF= np.array([0.8914,1.0014,1.0806,1.0096,1.176,0.9658,0.917,1.0259])
CAMF= np.array([0.8623,0.8425,0.8289,0.8211,0.8154,0.8084,0.8043,0.8038])
ICAMF= np.array([0.8518,0.8387,0.8149,0.8062,0.7967,0.7839,0.7692,0.7528])
Prop= np.array([0.7218,0.7189,0.7127,0.7057,0.6903,0.6783,0.6704,0.6701])

fig, ax = plt.subplots(1, 1)
ax.set(xlabel='Latent dimension', ylabel='MAE')

ax.plot(F,BMF, 'y', linestyle='dotted', marker='*', markersize=7, label = 'BMF', linewidth = 3)
ax.plot(F,SVDpp, 'k', linestyle='dotted', marker='*', markersize=7, label = 'SVD++', linewidth = 3)
ax.plot(F,PMF, 'm', linestyle='dashed', marker='h', markersize=7, label = 'PMF', linewidth = 3)
ax.plot(F,NMF, 'c', linestyle='dashdot', marker='D', markersize=7, label = 'NMF', linewidth = 3)
ax.plot(F,CAMF, 'r', linestyle='dotted', marker='^', markersize=8, label = 'CAMF', linewidth = 3)
ax.plot(F,ICAMF, 'b', linestyle='dashdot', marker='o', markersize=8, label = 'ICAMF', linewidth = 3)
ax.plot(F,Prop, 'g', marker='s', markersize=7, label = 'KCAMF', linewidth = 3)

ax.grid()
#ax.set_ylim((0,1))
plt.xticks(F)
#ax.legend(loc='center right',prop = {'size' : 9.5})

fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.savefig('MAE_Trip.png')
plt.show()

# %%
F = np.array([10, 20, 30, 40, 50, 60, 70, 80])
BMF= np.array([1.2453,1.2349,1.2884,1.2544,1.2441,1.2394,1.2771,1.2746])
SVDpp= np.array([1.0231,1.0138,1.0183,1.0139,1.0048,0.9829,0.9743,0.9702])
PMF= np.array([1.0269,1.0221,1.0211,1.0218,1.0214,1.0241,1.0222,1.0226])
NMF= np.array([1.0383,1.0226,1.0334,1.0357,1.0267,1.0271,1.0259,1.0211])
CPTF= np.array([1.6732,1.8249,1.6805,1.7263,1.5864,1.8005,1.7834,1.7934])
CAMF= np.array([1.0991,1.0775,1.0679,0.9963,0.9917,0.9794,0.9672,0.9628])
ICAMF = np.array([1.0383,1.0156,0.9974,0.9817,0.9782,0.9638,0.9603,0.9591])
Prop= np.array([0.9793,0.9682,0.9574,0.9386,0.9227,0.9184,0.9159,0.9114])

fig, ax = plt.subplots(1, 1)
ax.set(xlabel='Latent dimension', ylabel='RMSE') 
ax.plot(F,BMF, 'y', linestyle='dotted', marker='*', markersize=7, label = 'BMF', linewidth = 3)
ax.plot(F,SVDpp, 'k', linestyle='dotted', marker='*', markersize=7, label = 'SVD++', linewidth = 3)
ax.plot(F,PMF, 'm', linestyle='dashed', marker='h', markersize=7, label = 'PMF', linewidth = 3)
ax.plot(F,NMF, 'c', linestyle='dashdot', marker='D', markersize=7, label = 'NMF', linewidth = 3)
ax.plot(F,CAMF, 'r', linestyle='dotted', marker='^', markersize=8, label = 'CAMF', linewidth = 3)
ax.plot(F,ICAMF, 'b', linestyle='dashdot', marker='o', markersize=8, label = 'ICAMF', linewidth = 3)
ax.plot(F,Prop, 'g', marker='s', markersize=7, label = 'KCAMF', linewidth = 3)
ax.grid()
#ax.set_ylim((0,1))
plt.xticks(F)
#ax.legend(loc='center right',prop = {'size' : 9.5})

fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.savefig('RMSE_Music.png')
plt.show()

# %%
F = np.array([10, 20, 30, 40, 50, 60, 70, 80])
BMF= np.array([1.0413,1.0209,1.0682,1.0466,1.033,1.04104,1.0614,1.0507])
SVDpp= np.array([0.6713,0.6688,0.6587,0.6596,0.6539,0.6525,0.6482,0.6443])
PMF= np.array([0.6626,0.6576,0.6554,0.6578,0.6543,0.6588,0.6552,0.6554])
NMF= np.array([0.6934,0.6943,0.6738,0.6633,0.6604,0.6608,0.6584,0.6569])
CPTF= np.array([1.3594,1.4879,1.3255,1.3863,1.2625,1.4271,1.4647,1.4837])
CAMF= np.array([0.6891,0.6926,0.6728,0.6719,0.6683,0.6571,0.6403,0.6399])
ICAMF = np.array([0.6803,0.6792,0.6683,0.6592,0.6538,0.6475,0.6394,0.6305])
Prop= np.array([0.6378,0.6254,0.6179,0.6062,0.5974,0.5969,0.5942,0.5893])

fig, ax = plt.subplots(1, 1)
ax.set(xlabel='Latent dimension', ylabel='MAE') 
ax.plot(F,BMF, 'y', linestyle='dotted', marker='*', markersize=7, label = 'BMF', linewidth = 3)
ax.plot(F,SVDpp, 'k', linestyle='dotted', marker='*', markersize=7, label = 'SVD++', linewidth = 3)
ax.plot(F,PMF, 'm', linestyle='dashed', marker='h', markersize=7, label = 'PMF', linewidth = 3)
ax.plot(F,NMF, 'c', linestyle='dashdot', marker='D', markersize=7, label = 'NMF', linewidth = 3)
ax.plot(F,CAMF, 'r', linestyle='dotted', marker='^', markersize=8, label = 'CAMF', linewidth = 3)
ax.plot(F,ICAMF, 'b', linestyle='dashdot', marker='o', markersize=8, label = 'ICAMF', linewidth = 3)
ax.plot(F,Prop, 'g', marker='s', markersize=7, label = 'KCAMF', linewidth = 3)
ax.grid()
#ax.set_ylim((0,1))
plt.xticks(F)
#ax.legend(loc='center right',prop = {'size' : 9.5})

fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.savefig('MAE_Music.png')
plt.show()

# %%
F = np.array([10, 20, 30, 40, 50, 60, 70, 80])
without_trust= np.array([1.9431,1.7892,1.6441,1.3528,1.2987,1.2244,1.178,1.1465])
UserTrust= np.array([1.8592,1.6933,1.4534,1.2852,1.2239,0.9432,0.9417,0.9414])
ItemTrust= np.array([1.8831,1.7329,1.4862,1.3166,1.2672,0.9512,0.9521,0.9517])
AggregateTrust= np.array([1.6621,1.3251,1.2385,0.9989,0.9632,0.7834,0.7819,0.7818])

fig, ax = plt.subplots(1, 1)
ax.set(xlabel='Latent dimension', ylabel='RMSE')

ax.plot(F,without_trust, 'k', linestyle='dotted', marker='*', markersize=7, label = 'without_trust', linewidth = 3)
ax.plot(F,UserTrust, 'm', linestyle='dashed', marker='h', markersize=7, label = 'UserTrust', linewidth = 3)
ax.plot(F,ItemTrust, 'c', linestyle='dashdot', marker='D', markersize=7, label = 'ItemTrust', linewidth = 3)
ax.plot(F,AggregateTrust, 'r', linestyle='dotted', marker='^', markersize=8, label = 'AggregateTrust', linewidth = 3)

ax.grid()
plt.xticks(F)

fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.savefig('SVD++_RMSE_LDos.png')
plt.show()

# %%
F = np.array([10, 20, 30, 40, 50, 60, 70, 80])
without_trust= np.array([1.7431,1.720,1.6681,1.5674,1.4543,1.3244,1.2784,1.1465])
UserTrust= np.array([1.0967,0.9882,0.9517,0.9356,0.9187,0.8932,0.8714,0.8517])
ItemTrust= np.array([1.1603,1.0887,0.9844,0.9568,0.9421,0.9312,0.9221,0.9217])
AggregateTrust= np.array([0.9221,0.8966,0.8492,0.8311,0.7952,0.7834,0.7822,0.7816])

fig, ax = plt.subplots(1, 1)
ax.set(xlabel='Latent dimension', ylabel='RMSE')

ax.plot(F,without_trust, 'k', linestyle='dotted', marker='*', markersize=7, label = 'without_trust', linewidth = 3)
ax.plot(F,UserTrust, 'm', linestyle='dashed', marker='h', markersize=7, label = 'UserTrust', linewidth = 3)
ax.plot(F,ItemTrust, 'c', linestyle='dashdot', marker='D', markersize=7, label = 'ItemTrust', linewidth = 3)
ax.plot(F,AggregateTrust, 'r', linestyle='dotted', marker='^', markersize=8, label = 'AggregateTrust', linewidth = 3)

ax.grid()
plt.xticks(F)

fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.savefig('SVD++_RMSE_Travel.png')
plt.show()

# %%
F = np.array([10, 20, 30, 40, 50, 60, 70, 80])
without_trust= np.array([1.680,1.6712,1.6381,1.6146,1.5678,1.4842,1.4482,1.435])
UserTrust= np.array([0.9567,0.9399,0.9379,0.9358,0.9337,0.9132,0.9074,0.9007])
ItemTrust= np.array([1.1203,0.9673,0.9601,0.9644,0.9438,0.9418,0.9404,0.9367])
AggregateTrust= np.array([0.8921,0.8866,0.8692,0.8411,0.7782,0.7734,0.7699,0.7682])

fig, ax = plt.subplots(1, 1)
ax.set(xlabel='Latent dimension', ylabel='RMSE')

ax.plot(F,without_trust, 'k', linestyle='dotted', marker='*', markersize=7, label = 'without_trust', linewidth = 3)
ax.plot(F,UserTrust, 'm', linestyle='dashed', marker='h', markersize=7, label = 'UserTrust', linewidth = 3)
ax.plot(F,ItemTrust, 'c', linestyle='dashdot', marker='D', markersize=7, label = 'ItemTrust', linewidth = 3)
ax.plot(F,AggregateTrust, 'r', linestyle='dotted', marker='^', markersize=8, label = 'AggregateTrust', linewidth = 3)

ax.grid()
plt.xticks(F)

fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.savefig('SVD++_RMSE_InCarMusic.png')
plt.show()

# %%
F = np.array([10, 20, 30, 40, 50, 60, 70, 80])
without_trust= np.array([1.9631,1.892,1.8429,1.7863,1.7523,1.6544,1.5743,1.535])
UserTrust= np.array([1.8992,1.7433,1.6234,1.4652,1.3839,1.3232,1.1914,1.1117])
ItemTrust= np.array([1.9131,1.7629,1.6562,1.5269,1.4674,1.3712,1.2521,1.2013])
AggregateTrust= np.array([1.6821,1.571,1.4085,1.3789,1.2637,1.2033,1.1419,1.0422])

fig, ax = plt.subplots(1, 1)
ax.set(xlabel='Latent dimension', ylabel='RMSE')

ax.plot(F,without_trust, 'k', linestyle='dotted', marker='*', markersize=7, label = 'without_trust', linewidth = 3)
ax.plot(F,UserTrust, 'm', linestyle='dashed', marker='h', markersize=7, label = 'UserTrust', linewidth = 3)
ax.plot(F,ItemTrust, 'c', linestyle='dashdot', marker='D', markersize=7, label = 'ItemTrust', linewidth = 3)
ax.plot(F,AggregateTrust, 'r', linestyle='dotted', marker='^', markersize=8, label = 'AggregateTrust', linewidth = 3)

ax.grid()
plt.xticks(F)

fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.savefig('SVD++_RMSE_DePaulMovie.png')
plt.show()

# %%
F = np.array([10, 20, 30, 40, 50, 60, 70])
F = np.array(['MFCF', 'CARS', 'TBRS', 'TFRS-CR', 'TFRS-CR-UT', 'TFRS-CR-IT', 'TFRS-CR-AT'])
without_trust= np.array([1.9631,1.892,1.8429,1.7863,1.7523,1.6544,1.5743])
UserTrust= np.array([1.8992,1.7433,1.6234,1.4652,1.3839,1.3232,1.1914])

fig, ax = plt.subplots(1, 1)
ax.set(xlabel='Recommendation Technique', ylabel='RMSE')

ax.plot(F,without_trust, 'k', linestyle='dotted', marker='*', markersize=7, label = 'without_trust', linewidth = 3)
ax.plot(F,UserTrust, 'm', linestyle='dashed', marker='h', markersize=7, label = 'UserTrust', linewidth = 3)
ax.set_xticklabels(F, rotation=25, fontname='Verdana', fontsize=15)
ax.set_yticklabels(fontname='Verdana', fontsize=15)
ax.legend(loc='upper right',prop = {'size' : 9.5})
ax.grid()
plt.xticks(F)

fig.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)
plt.savefig('TFRS_CMP_RMSE_LDOS.png')
plt.show()
